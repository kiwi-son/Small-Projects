# %%
import yagmail

# %%
yag = yagmail.SMTP(
    "EMAIL_ADDRESS",
    "EMAIL_PASSWORD"
)

# %%
yag.send(
    to="jeetsadhukhan2305@gmail.com",
    subject="Shift Schedule Reminder Mail",
    contents="This is a shift schedule reminder mail"
)
# Out:
# {}
